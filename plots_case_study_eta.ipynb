# %%
#plot use case
#    model.addConstrs(  (rho[t] == gb.quicksum(rho_bar[t] * ((1 - alpha)**(tau - 1))*z[j,tau] for tau in range(1, t+1) for j in F) for t in T), name = 'ctRho' )
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
f1 = 'results/eta_values_2.xlsx'

# %%
df = pd.read_excel(f1)
#df.rename(columns={'eta*z1':'z1', (1.eta)*z2 	objval 	eta},inplace=True)
df
# Out:
#              z1           z2      objval    eta         ez1         ez2
# 0  29818.346154   737.280000  737.280000  0.000    0.000000  737.280000
# 1    417.516754   898.437575  838.322472  0.125   52.189594  786.132878
# 2    466.360927   817.787572  729.930911  0.250  116.590232  613.340679
# 3    284.842402  1080.009726  781.821980  0.375  106.815901  675.006079
# 4    331.625776  1040.854495  686.240135  0.500  165.812888  520.427247
# 5    230.368741  1142.849951  572.549195  0.625  143.980463  428.568732
# 6    215.371083  1243.537441  472.412673  0.750  161.528313  310.884360
# 7    151.314991  1563.207019  327.801495  0.875  132.400617  195.400877
# 8     59.691312  7371.180000   59.691312  1.000   59.691312    0.000000

# %%
ax = plt.figure().add_subplot()
ax.plot(df['eta'], df['z1'], ls='dashed', color = 'r', label=r"$ Z^{'}$")
ax.plot(df['eta'], df['z2'], ls='dotted', color = 'g', label=r"$ Z^{''}$")
ax.plot(df['eta'], df['z1'] +df['z2'], ls='solid', color = 'b', label=r"$Z$")
ax.set_xticks(df['eta'])
ax.set_xlabel("$\eta$")
ax.set_ylabel(r"kgCO$_{\mathrm{2}}$")
ax.legend()
#plt.show()
plt.savefig("results/use_case_eta/caseStudyEta2.png", dpi = 600)
